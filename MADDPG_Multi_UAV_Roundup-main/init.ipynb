# %%
#获取
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
path="/content/drive/My Drive/MADDPG_Multi_UAV_Roundup-main"
os.chdir(path)
os.listdir(path)
# Out:
# ['README.md',
#  'buffer.py',
#  'LICENSE',
#  'math_tool.py',
#  'UAV.png',
#  'Roundup.png',
#  'maddpg.py',
#  'agent.py',
#  'main.py',
#  'networks.py',
#  'score_history.csv',
#  'sim_env.py',
#  'main_evaluate.py',
#  '__pycache__',
#  'frames_output',
#  'images',
#  'tmp']

# %%
# !python main_evaluate.py
# Out:
# ... loading checkpoint ...
# ---- Evaluating ----
# Round-up finished in 96 steps.
